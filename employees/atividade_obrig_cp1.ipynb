# %%
import pandas as pd

# %%
#1
df = pd.read_csv(r"C:\Users\diego\Downloads\DataScience\employees\employees.csv")
df
# Out:
#     ID              Nome  Idade                    Cargo  Salário  \
# 0    1         Ana Silva     34        Analista de Dados     7500
# 1    2       Carlos Lima     29       Cientista de Dados    10500
# 2    3     Beatriz Souza     41      Gerente de Projetos    15000
# 3    4       João Mendes     38            Desenvolvedor     8200
# 4    5    Fernanda Rocha     26              UX Designer     6700
# 5    6    Marcos Andrade     32   Engenheiro de Software    11500
# 6    7     Luciana Alves     30                      DBA     9800
# 7    8     Ricardo Pinto     40    Analista de Segurança     8700
# 8    9    Gabriela Costa     27           Analista de BI     9200
# 9   10    Paulo Oliveira     36             Scrum Master    10800
# 10  11   Vanessa Martins     45    Arquiteto de Software    14500
# 11  12    Thiago Ribeiro     31            Desenvolvedor     8600
# 12  13    Patrícia Nunes     29            Gerente de TI    15800
# ...

# %%
#2
df[df['Departamento']=='TI']

# %%
#3
media_sal = df['Salário'].mean()
print(f"A média dos salários dos funcionários é de R$ {media_sal}")
# Out:
# A média dos salários dos funcionários é de R$ 11540.0

# %%
#4

df['Data_Admissão'] = pd.to_datetime(df['Data_Admissão'], format= '%d/%m/%Y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 3
#       1 #4
# ----> 3 df['Data_Admissão'] = pd.to_datetime(df['Data_Admissão'], format = '%d/%m/%Y')
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\tools\datetimes.py:1067, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1065         result = arg.map(cache_array)
#    1066     else:
# -> 1067         values = convert_listlike(arg._values, format)
#    1068         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1069 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\tools\datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
# ...
